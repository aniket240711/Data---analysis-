# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install -q kaleido

# %%
# !pip install -U kaleido

# %%
df = pd.read_csv('zomato.csv')
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.drop(columns=['url','phone','reviews_list','menu_item'], inplace=True)

# %%
df.dtypes
# Out:
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
df.isnull()
# Out:
#        address   name  online_order  book_table   rate  votes  location  \
# 0        False  False         False       False  False  False     False
# 1        False  False         False       False  False  False     False
# 2        False  False         False       False  False  False     False
# 3        False  False         False       False  False  False     False
# 4        False  False         False       False  False  False     False
# ...        ...    ...           ...         ...    ...    ...       ...
# 51712    False  False         False       False  False  False     False
# 51713    False  False         False       False   True  False     False
# 51714    False  False         False       False   True  False     False
# 51715    False  False         False       False  False  False     False
# 51716    False  False         False       False  False  False     False
#
#        rest_type  dish_liked  cuisines  approx_cost(for two people)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51717 non-null  object
#  1   name                         51717 non-null  object
#  2   online_order                 51717 non-null  object
#  3   book_table                   51717 non-null  object
#  4   rate                         43942 non-null  object
#  5   votes                        51717 non-null  int64
#  6   location                     51696 non-null  object
#  7   rest_type                    51490 non-null  object
#  8   dish_liked                   23639 non-null  object
#  9   cuisines                     51672 non-null  object
#  10  approx_cost(for two people)  51371 non-null  object
#  11  listed_in(type)              51717 non-null  object
#  12  listed_in(city)              51717 non-null  object
# ...

# %%
df['rate'] = df['rate'].astype(str).str.replace('/5', '', regex=False)

# %%
df['rate'] = pd.to_numeric(df['rate'], errors='coerce')
df['rate'] = df['rate'].fillna(0)

# %%
display(df[['rate']].head())
display(df['rate'].dtype)
# Out:
#    rate
# 0   4.1
# 1   4.1
# 2   3.8
# 3   3.7
# 4   3.8
# dtype('float64')

# %%
df['approx_cost(for two people)']= pd.to_numeric(df['approx_cost(for two people)'], errors='coerce')
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].fillna(0).astype(int)

display(df[['approx_cost(for two people)']].head())
display(df['approx_cost(for two people)'].dtype)
# Out:
#    approx_cost(for two people)
# 0                          800
# 1                          800
# 2                          800
# 3                          300
# 4                          600
# dtype('int64')

# %%
overall_average_cost = df['approx_cost(for two people)'].mean()
print(f"Overall Average Cost for two people: {overall_average_cost:.2f}")
# Out:
# Overall Average Cost for two people: 358.12

# %%
top_restaurants_by_cost = average_cost_per_restaurant.sort_values(ascending=False).head(10)

fig = px.bar(
    top_restaurants_by_cost,
    x=top_restaurants_by_cost.index,
    y=top_restaurants_by_cost.values,
    title='Top 10 Restaurants by Average Cost for Two People',
    labels={'x': 'Restaurant Name', 'y': 'Average Cost for Two People'}
)

fig.update_layout(xaxis_tickangle=-45, width = 1000 , height = 600)
fig.show()

print(f"\nOverall Average Cost for two people: {overall_average_cost:.2f}")
print("\nAverage Costs for the Top 10 Restaurants:")
print(top_restaurants_by_cost.to_string())
# Out:
# Overall Average Cost for two people: 358.12
#
# Average Costs for the Top 10 Restaurants:
# name
# The Onyx - The HHI Select Bengaluru    950.0
# Ayda Persian Kitchen                   950.0
# Bathinda Dine                          950.0
# Inchara                                950.0
# Engine                                 950.0
# Pindi Bangalore                        925.0
# The Kim Chi Chef                       900.0
# The Dhaba                              900.0
# The Cake Post                          900.0
# Kadal Da Meen                          900.0

# %%
The overall average cost for two people across all restaurants is 358.12.

The average cost for two people for individual restaurants varies significantly, with some establishments having much higher average costs.

The top 10 restaurants by average cost for two people have costs ranging from 900.0 to 950.0.

Specific examples of top restaurants by average cost include 'The Onyx - The HHI Select Bengaluru',
'Ayda Persian Kitchen', 'Bathinda Dine', 'Inchara', 'Engine', 'Pindi Bangalore', 'The Kim Chi Chef', 'The Dhaba', 'The Cake Post', and 'Kadal Da Meen'.

# %%
average_cost_per_restaurant = df.groupby('name')['approx_cost(for two people)'].mean()
print("Average Cost per Restaurant (first 5 entries):")
display(average_cost_per_restaurant.head())
# Out:
# Average Cost per Restaurant (first 5 entries):
# name
# #FeelTheROLL              200.0
# #L-81 Cafe                400.0
# #Vibes Restro             700.0
# #refuel                   400.0
# 'Brahmins' Thatte Idli    100.0
# Name: approx_cost(for two people), dtype: float64

# %%
df.dtypes
# Out:
# address                         object
# name                            object
# online_order                    object
# book_table                      object
# rate                           float64
# votes                            int64
# location                        object
# rest_type                       object
# dish_liked                      object
# cuisines                        object
# approx_cost(for two people)      int64
# listed_in(type)                 object
# listed_in(city)                 object
# dtype: object

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

print(f"Numerical Columns: {numerical_cols}")
print(f"Categorical Columns: {categorical_cols}")
# Out:
# Numerical Columns: ['rate', 'votes', 'approx_cost(for two people)']
# Categorical Columns: ['address', 'name', 'online_order', 'book_table', 'location', 'rest_type', 'dish_liked', 'cuisines', 'listed_in(type)', 'listed_in(city)']

# %%
df.duplicated().sum()
# Out:
# np.int64(85)

# %%
df.describe()
# Out:
#                rate         votes  approx_cost(for two people)
# count  51717.000000  51717.000000                 51717.000000
# mean       2.981209    283.697527                   358.119671
# std        1.516766    803.838853                   231.321828
# min        0.000000      0.000000                     0.000000
# 25%        3.000000      7.000000                   200.000000
# 50%        3.600000     41.000000                   350.000000
# 75%        3.900000    198.000000                   500.000000
# max        4.900000  16832.000000                   950.000000

# %%
online_order_values = df['online_order'].unique()
print(online_order_values)
# Out:
# ['Yes' 'No']

# %%
restaurants_per_location = df['location'].value_counts()
print("Number of restaurants per location:")
display(restaurants_per_location)
# Out:
# Number of restaurants per location:
# location
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# Yelahanka                   6
# West Bangalore              6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: count, Length: 93, dtype: int64

# %%
top_20_locations = restaurants_per_location.head(20)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_20_locations.index, y=top_20_locations.values, palette='viridis')
plt.title('Top 20 Locations by Number of Restaurants')
plt.xlabel('Location')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()
plt.show()

# %%
online_order_counts = df['online_order'].value_counts()
print("Number of restaurants delivering vs. not delivering:")
print(online_order_counts)
# Out:
# Number of restaurants delivering vs. not delivering:
# online_order
# Yes    30444
# No     21273
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.pie(online_order_counts.values, labels=online_order_counts.index, autopct='%1.2f%%', shadow = True , startangle=90, explode = [0,0.1], colors=['orange', 'teal'])
plt.title('Proportion of Restaurants by Online Order Availability')
plt.axis('equal') 
plt.show()

# %%
total_locations = df['location'].nunique()
print(f"Total number of unique locations: {total_locations}")
# Out:
# Total number of unique locations: 93

# %%
delivering_restaurants = df[df['online_order'] == 'Yes']

location_delivery_counts = delivering_restaurants['location'].value_counts()
top_10_delivering_locations = location_delivery_counts.head(11)
print("Top 20 locations with the highest number of restaurants delivering online:")
display(top_20_delivering_locations)
# Out:
# Top 20 locations with the highest number of restaurants delivering online:
# location
# BTM                      3332
# HSR                      1920
# Koramangala 5th Block    1614
# Jayanagar                1364
# Indiranagar              1335
# JP Nagar                 1318
# Whitefield               1139
# Marathahalli             1112
# Bannerghatta Road         924
# Koramangala 1st Block     853
# Koramangala 7th Block     786
# Bellandur                 761
# Sarjapur Road             729
# Koramangala 6th Block     699
# Brigade Road              665
# Ulsoor                    628
# Electronic City           577
# Koramangala 4th Block     558
# Banashankari              509
# Kalyan Nagar              498
# Name: count, dtype: int64

# %%
fig = px.pie(names=top_10_delivering_locations.index,
             values=top_10_delivering_locations.values,
             title='Top 10 Locations by Number of Online Delivering Restaurants',
             color_discrete_sequence=px.colors.sequential.RdBu,
             hole=0.3)

fig.update_traces(textinfo='percent+label', pull=[0.05] * len(top_10_delivering_locations)) 
fig.show()

# %%
book_table_counts = df['book_table'].value_counts()
print("Number of restaurants with table booking vs. without:")
display(book_table_counts)
# Out:
# Number of restaurants with table booking vs. without:
# book_table
# No     45268
# Yes     6449
# Name: count, dtype: int64

# %%
fig = px.pie(names=book_table_counts.index,
             values=book_table_counts.values,
             title='Proportion of Restaurants by Table Booking Availability',
             color_discrete_sequence=px.colors.sequential.RdBu,
             hole=0.3)

fig.update_traces(textinfo='percent+label', pull=[0.05] * len(book_table_counts))
fig.show()

# %%
restaurants_per_location = df['location'].value_counts()
print("Number of restaurants per location:")
display(restaurants_per_location)
# Out:
# Number of restaurants per location:
# location
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# Yelahanka                   6
# West Bangalore              6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: count, Length: 93, dtype: int64

# %%
top_20_locations = restaurants_per_location.head(20)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_20_locations.index, y=top_20_locations.values, palette='viridis')
plt.title('Top 20 Locations by Number of Restaurants')
plt.xlabel('Location')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
top_10_locations = restaurants_per_location.head(10)

fig = px.pie(names=top_10_locations.index,
             values=top_10_locations.values,
             title='Top 10 Locations by Number of Restaurants',
             color_discrete_sequence=px.colors.sequential.Plasma,
             hole=0.3)

fig.update_traces(textinfo='percent+label', pull=[0.05] * len(top_10_locations))
fig.show()

# %%
restaurant_chain_counts = df['name'].value_counts()
top_10_chains = restaurant_chain_counts.head(10)

fig = px.pie(names=top_10_chains.index,
             values=top_10_chains.values,
             title='Top 10 Most Famous Restaurant Chains in Bengaluru (Percentage)',
             color_discrete_sequence=px.colors.sequential.Agsunset,
             hole=0.3)

fig.update_traces(textinfo='percent+label', pull=[0.05] * len(top_10_chains)) # Slightly pull out slices for better visibility
fig.show()

# %%
avg_rating_per_location = df.groupby('location')['rate'].mean().sort_values(ascending=False)
print("Top 10 Locations by Average Rating:")
display(avg_rating_per_location.head(10))

print("Bottom 10 Locations by Average Rating:")
display(avg_rating_per_location.tail(10))
# Out:
# Top 10 Locations by Average Rating:
# location
# St. Marks Road           3.914489
# Rajarajeshwari Nagar     3.850000
# Church Street            3.830756
# Sankey Road              3.818519
# Lavelle Road             3.813611
# Langford Town            3.807407
# Cunningham Road          3.773931
# Kengeri                  3.722222
# Koramangala 5th Block    3.709864
# Race Course Road         3.673381
# Name: rate, dtype: float64
# Bottom 10 Locations by Average Rating:
# location
# Jalahalli         2.110526
# Ejipura           2.059681
# Hebbal            2.057143
# KR Puram          1.966667
# Shivajinagar      1.942285
# Bommanahalli      1.930672
# Uttarahalli       1.858824
# West Bangalore    1.683333
# Nagarbhavi        0.377778
# Jakkur            0.000000
# Name: rate, dtype: float64

# %%
top_10_avg_ratings = avg_rating_per_location.head(11)

results = []

for loc, avg_rate in top_10_avg_ratings.items():

    cities = df[df['location'] == loc]['listed_in(city)'].unique()

    city_str = ', '.join(cities)
    results.append({'Location': loc, 'Average Rating': avg_rate, 'Listed In City': city_str})

output_df = pd.DataFrame(results)
display(output_df)
# Out:
#                  Location  Average Rating  \
# 0          St. Marks Road        3.914489
# 1    Rajarajeshwari Nagar        3.850000
# 2           Church Street        3.830756
# 3             Sankey Road        3.818519
# 4            Lavelle Road        3.813611
# 5           Langford Town        3.807407
# 6         Cunningham Road        3.773931
# 7                 Kengeri        3.722222
# 8   Koramangala 5th Block        3.709864
# 9        Race Course Road        3.673381
# 10      Central Bangalore        3.625000
#
#                                        Listed In City
# 0   Brigade Road, Church Street, Frazer Town, Lave...
# 1                                        Banashankari
# 2   Brigade Road, Church Street, Frazer Town, Indi...
# 3                          Lavelle Road, Malleshwaram
# 4   Brigade Road, Church Street, Frazer Town, Lave...
# 5   Brigade Road, Church Street, Koramangala 7th B...
# 6   Brigade Road, Church Street, Frazer Town, Lave...
# ...

# %%
fig = px.bar(output_df,
             x='Location',
             y='Average Rating',
             color='Average Rating',
             color_continuous_scale=px.colors.sequential.Plasma,
             title='Top 10 Locations by Average Restaurant Rating (with Listed Cities)',
             hover_data={'Listed In City': True, 'Average Rating': ':.2f'})

fig.update_layout(xaxis_title='Location',
                  yaxis_title='Average Rating',
                  xaxis_tickangle=-45,width = 1000, height = 600)
fig.show()

# %%
top_10_avg_ratings = avg_rating_per_location.head(10)

results = []

for loc, avg_rate in top_10_avg_ratings.items():

    cities = df[df['location'] == loc]['listed_in(city)'].unique()
    city_str = ', '.join(cities)
    results.append({'Location': loc, 'Average Rating': avg_rate, 'Listed In City': city_str})

output_df = pd.DataFrame(results)
display(output_df)
# Out:
#                 Location  Average Rating  \
# 0         St. Marks Road        3.914489
# 1   Rajarajeshwari Nagar        3.850000
# 2          Church Street        3.830756
# 3            Sankey Road        3.818519
# 4           Lavelle Road        3.813611
# 5          Langford Town        3.807407
# 6        Cunningham Road        3.773931
# 7                Kengeri        3.722222
# 8  Koramangala 5th Block        3.709864
# 9       Race Course Road        3.673381
#
#                                       Listed In City
# 0  Brigade Road, Church Street, Frazer Town, Lave...
# 1                                       Banashankari
# 2  Brigade Road, Church Street, Frazer Town, Indi...
# 3                         Lavelle Road, Malleshwaram
# 4  Brigade Road, Church Street, Frazer Town, Lave...
# 5  Brigade Road, Church Street, Koramangala 7th B...
# 6  Brigade Road, Church Street, Frazer Town, Lave...
# 7                         Kalyan Nagar, Kammanahalli
# ...

# %%
total_rest_types = df['rest_type'].nunique()
print(f"Total number of unique restaurant types: {total_rest_types}")

# %%
top_10_rest_types = df['rest_type'].value_counts().head(10)
print("Top 10 most common restaurant types:")
display(top_10_rest_types)
# Out:
# Top 10 most common restaurant types:
# rest_type
# Quick Bites           19132
# Casual Dining         10330
# Cafe                   3732
# Delivery               2604
# Dessert Parlor         2263
# Takeaway, Delivery     2037
# Casual Dining, Bar     1154
# Bakery                 1141
# Beverage Shop           867
# Bar                     697
# Name: count, dtype: int64

# %%
df['dish_liked'].fillna('', inplace=True)

all_dishes = df['dish_liked'].apply(lambda x: [dish.strip() for dish in x.split(',') if dish.strip() != ''])

flat_dishes = [dish for sublist in all_dishes for dish in sublist]

dish_counts = pd.Series(flat_dishes).value_counts()

print("Top 10 most liked dishes overall:")
display(dish_counts.head(10))
# Out:
# Top 10 most liked dishes overall:
# Pasta         3409
# Burgers       3024
# Cocktails     2832
# Pizza         2737
# Biryani       2092
# Coffee        1994
# Mocktails     1887
# Sandwiches    1676
# Paratha       1566
# Noodles       1415
# Name: count, dtype: int64

# %%
df['cuisines'].fillna('', inplace=True)
all_cuisines = df['cuisines'].apply(lambda x: [cuisine.strip() for cuisine in x.split(',') if cuisine.strip() != ''])
flat_cuisines = [cuisine for sublist in all_cuisines for cuisine in sublist]
cuisine_counts = pd.Series(flat_cuisines).value_counts()

print("Top 10 most provided cuisines overall:")
display(cuisine_counts.head(10))
# Out:
# Top 10 most provided cuisines overall:
# North Indian    21085
# Chinese         15547
# South Indian     8644
# Fast Food        8096
# Biryani          6492
# Continental      5765
# Desserts         5633
# Cafe             5303
# Beverages        4747
# Italian          3389
# Name: count, dtype: int64

# %%
listed_in_type_counts = df['listed_in(type)'].value_counts()
print("Total restaurants per listed type:")
display(listed_in_type_counts)
# Out:
# Total restaurants per listed type:
# listed_in(type)
# Delivery              25942
# Dine-out              17779
# Desserts               3593
# Cafes                  1723
# Drinks & nightlife     1101
# Buffet                  882
# Pubs and bars           697
# Name: count, dtype: int64

# %%
#To understand the distribution of ratings for different restaurant types, we'll plot a Kernel Density Estimate (KDE).
#This will help us see if the ratings for certain types of restaurants tend to cluster around an average
#(like a 'gaussian' or normal distribution) or if they are spread out differently.

# %%
top_5_rest_types = df['rest_type'].value_counts().head(5).index

filtered_df_for_kde = df[df['rest_type'].isin(top_5_rest_types) & (df['rate'] > 0)]

plt.figure(figsize=(12, 8))
sns.kdeplot(data=filtered_df_for_kde, x='rate', hue='rest_type', fill=True, common_norm=False, palette='viridis', alpha=0.6, linewidth=2)
plt.title('Distribution of Ratings for Top 5 Restaurant Types')
plt.xlabel('Rating (out of 5)')
plt.ylabel('Density')
plt.legend(title='Restaurant Type')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Here's the break down of the insights from this KDE plot showing the distribution of ratings for the top 5 restaurant types:

#General Trend: Most of the top restaurant types (Quick Bites, Casual Dining, Cafe, Delivery, Dessert Parlor) show a fairly concentrated distribution of ratings, primarily peaking between 3.0 and 4.0, which suggests that the majority of restaurants receive moderate to good ratings.

#'Cafe' and 'Dessert Parlor': These categories also show a strong peak in the 3.5 to 4.0 range. 'Cafe' appears to have a slightly wider spread, implying a bit more variability in ratings compared to 'Quick Bites' or 'Casual Dining'.

#'Dessert Parlor' has a relatively tight peak, possibly indicating a more consistent level of customer satisfaction.

#'Delivery': The 'Delivery' category also has a peak around the same range (3.5-3.8), but its curve might be slightly flatter or wider than 'Quick Bites' or 'Casual Dining', suggesting a broader range of ratings or perhaps that 'Delivery' is an attribute of a restaurant rather than a distinct type, hence its ratings might reflect the underlying restaurant type more.

#Lower Rated Restaurants: All types show a drop-off towards the lower ratings (below 2.0-2.5), which is a positive sign, indicating fewer restaurants are consistently poorly rated.

#In essence, the plot reveals that most of the popular restaurant types tend to receive ratings in the 'good' to 'very good' range, with a relatively low proportion of establishments receiving consistently low scores.

# %%
listed_in_type_counts = df['listed_in(type)'].value_counts()
print("Total restaurants per listed type:")
display(listed_in_type_counts)
# Out:
# Total restaurants per listed type:
# listed_in(type)
# Delivery              25942
# Dine-out              17779
# Desserts               3593
# Cafes                  1723
# Drinks & nightlife     1101
# Buffet                  882
# Pubs and bars           697
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=listed_in_type_counts.index, y=listed_in_type_counts.values, palette='viridis')
plt.title('Total Restaurants per Listed Type')
plt.xlabel('Listed Type')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
avg_rating_by_listed_type = df.groupby('listed_in(type)')['rate'].mean().sort_values(ascending=False)
print("Average Rating by Listed Type:")
display(avg_rating_by_listed_type)
# Out:
# Average Rating by Listed Type:
# listed_in(type)
# Buffet                3.860204
# Drinks & nightlife    3.849228
# Pubs and bars         3.699713
# Cafes                 3.429716
# Dine-out              2.941307
# Delivery              2.907875
# Desserts              2.871918
# Name: rate, dtype: float64

# %%
plt.figure(figsize=(12, 7))
sns.barplot(x=avg_rating_by_listed_type.index, y=avg_rating_by_listed_type.values, palette='viridis')
plt.title('Average Rating by Restaurant Service Type')
plt.xlabel('Listed Type')
plt.ylabel('Average Rating')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
restaurant_chain_counts = df['name'].value_counts()
print("Top 10 most famous restaurant chains in Bengaluru (by number of outlets):")
display(restaurant_chain_counts.head(11))
# Out:
# Top 10 most famous restaurant chains in Bengaluru (by number of outlets):
# name
# Cafe Coffee Day      96
# Onesta               85
# Just Bake            73
# Empire Restaurant    71
# Five Star Chicken    70
# Kanti Sweets         68
# Petoo                66
# Polar Bear           65
# Baskin Robbins       64
# Pizza Hut            62
# Chef Baker's         62
# Name: count, dtype: int64

# %%
top_10_chains = restaurant_chain_counts.head(10)

fig = px.pie(names=top_10_chains.index,
             values=top_10_chains.values,
             title='Top 10 Most Famous Restaurant Chains in Bengaluru (Percentage)',
             color_discrete_sequence=px.colors.sequential.Agsunset,
             hole=0.3)

fig.update_traces(textinfo='percent+label', pull=[0.05] * len(top_10_chains)) # Slightly pull out slices for better visibility
fig.show()

# %%
#Data Overview and Preparation: We started by loading a substantial dataset of over 51,000 restaurant entries. Initial cleaning involved dropping irrelevant identifiers (url, phone, reviews_list, menu_item) and converting rate and approx_cost to numerical formats, handling missing values appropriately.

#Online Ordering Dominance: A significant majority of restaurants (approximately 59%) offer online ordering, indicating a strong presence of digital food delivery services in Bengaluru. This suggests that convenience is a major factor for consumers in the city.

#Limited Table Booking: In contrast to online ordering, only a small percentage (around 12%) of restaurants offer table booking. This implies that most establishments operate on a walk-in basis, or table booking is less of a focus for the broader restaurant market captured in this dataset.

#Restaurant Hotspots in Bengaluru: Locations like BTM, HSR, and Koramangala 5th Block are clearly the major restaurant hubs, hosting the highest number of establishments. This concentration suggests these areas are key commercial or residential zones with high demand for dining options.

#Locations with High Average Ratings: While popular areas have many restaurants, areas like St. Marks Road, Rajarajeshwari Nagar, and Church Street boast the highest average customer ratings. This could indicate a higher concentration of quality establishments or a different dining experience in these specific locations.

#Popular Cuisines and Dishes: North Indian and Chinese cuisines are the most widely available across restaurants. For individual dishes, Pasta, Burgers, Cocktails, and Pizza appear to be the most frequently liked, showcasing a blend of international and popular comfort food preferences.

#Restaurant Type Landscape: The dataset features a diverse range of 93 unique restaurant types. 'Quick Bites' and 'Casual Dining' are overwhelmingly the most common types, accounting for a large portion of the restaurants. Other significant types include Cafes, Delivery-only outlets, and Dessert Parlors.

#Rating Distribution by Restaurant Type: The KDE plot revealed that most popular restaurant types ('Quick Bites', 'Casual Dining', 'Cafe', 'Delivery', 'Dessert Parlor') show a positive rating distribution, primarily peaking between 3.0 and 4.0. This indicates generally good customer satisfaction across these prevalent types, with fewer establishments receiving consistently low scores.

#Restaurant Service Types and Ratings: When looking at listed_in(type), 'Buffet' and 'Drinks & nightlife' categories tend to have the highest average ratings, suggesting higher customer satisfaction for these dining experiences. 'Delivery' and 'Desserts' categories, while popular in volume, show slightly lower average ratings, possibly due to factors inherent to those service models.

#Dominant Restaurant Chains: Chains like Cafe Coffee Day, Onesta, and Just Bake have the highest number of outlets, indicating their widespread presence and likely strong brand recognition across Bengaluru.

#In summary, the Bengaluru food scene is vibrant, dominated by casual and quick dining options, with strong online delivery adoption. While certain areas are restaurant-dense, others stand out for higher average customer satisfaction. The variety of cuisines and dishes caters to a broad palate, with a clear preference for commonly liked items.
